# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trends=pd.read_csv("shopping_trends.csv",index_col=[0])
trends
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends_updated=pd.read_csv("shopping_trends_updated.csv",index_col=[0])
trends_updated
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends.shape#there is 3900 rows and 18 columns
# Out:
# (3900, 18)

# %%
trends.dtypes
# Out:
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
trends.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
trends["Gender"].value_counts()#male did more shopping than women
# Out:
# Male      2652
# Female    1248
# Name: Gender, dtype: int64

# %%
trends["Category"].value_counts()#max shopping was done under clothing category
# Out:
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: Category, dtype: int64

# %%
trends["Season"].value_counts()#almost all season shopping trend is similar
# Out:
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: Season, dtype: int64

# %%
trends["Payment Method"].value_counts()
# Out:
# Credit Card      696
# Venmo            653
# Cash             648
# PayPal           638
# Debit Card       633
# Bank Transfer    632
# Name: Payment Method, dtype: int64

# %%
trends["Age"].min()
# Out:
# 18

# %%
trends["Age"].max()
# Out:
# 70

# %%
category_group=trends.groupby("Category")

# %%
category_group["Item Purchased"].value_counts()
# Out:
# Category     Item Purchased
# Accessories  Jewelry           171
#              Belt              161
#              Sunglasses        161
#              Scarf             157
#              Hat               154
#              Handbag           153
#              Backpack          143
#              Gloves            140
# Clothing     Blouse            171
#              Pants             171
#              Shirt             169
#              Dress             166
#              Sweater           164
#              Socks             159
#              Skirt             158
#              Shorts            157
#              Hoodie            151
#              T-shirt           147
#              Jeans             124
# Footwear     Sandals           160
#              Shoes             150
#              Sneakers          145
#              Boots             144
# Outerwear    Jacket            163
#              Coat              161
# Name: Item Purchased, dtype: int64

# %%
pay_method_group=trends.groupby("Payment Method")
pay_method_group[["Category","Item Purchased","Purchase Amount (USD)"]].get_group("Credit Card").
# Out:
#   Cell In[30], line 2
#     pay_method_group[["Category","Item Purchased","Purchase Amount (USD)"]].get_group("Credit Card").
#                                                                                                      ^
# SyntaxError: invalid syntax

# %%
pay_method_group[["Category","Item Purchased"]].get_group("Credit Card").value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pay_method_group[["Category","Item Purchased"]].get_group("Credit Card").value_counts()
#
# NameError: name 'pay_method_group' is not defined

# %%
trends1=trends.loc[:,["Category","Age"]]
trends1

# %%
trends1.plot(kind="bar")

# %%
clothing_creditcard=(trends["Category"]=="Clothing")&(trends["Payment Method"]=="Credit Card")

# %%
pd.DataFrame(clothing_creditcard).value_counts()

# %%
trends.loc[:,("Discount Applied","Previous Purchases")]

# %%
plt.bar(trends["Subscription Status"],trends["Review Rating"])
# Out:
# <BarContainer object of 3900 artists>

# %%
plt.bar(trends["Category"],trends["Review Rating"])
# Out:
# <BarContainer object of 3900 artists>

# %%
trends["Location"].unique()
# Out:
# array(['Kentucky', 'Maine', 'Massachusetts', 'Rhode Island', 'Oregon',
#        'Wyoming', 'Montana', 'Louisiana', 'West Virginia', 'Missouri',
#        'Arkansas', 'Hawaii', 'Delaware', 'New Hampshire', 'New York',
#        'Alabama', 'Mississippi', 'North Carolina', 'California',
#        'Oklahoma', 'Florida', 'Texas', 'Nevada', 'Kansas', 'Colorado',
#        'North Dakota', 'Illinois', 'Indiana', 'Arizona', 'Alaska',
#        'Tennessee', 'Ohio', 'New Jersey', 'Maryland', 'Vermont',
#        'New Mexico', 'South Carolina', 'Idaho', 'Pennsylvania',
#        'Connecticut', 'Utah', 'Virginia', 'Georgia', 'Nebraska', 'Iowa',
#        'South Dakota', 'Minnesota', 'Washington', 'Wisconsin', 'Michigan'],
#       dtype=object)

# %%
female_with_accesories=trends[(trends["Gender"]=="Female") & (trends["Category"]=="Accessories")]

# %%
female_with_accesories
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 2656          26  Female     Sunglasses  Accessories                     83
# 2659          52  Female        Handbag  Accessories                     47
# 2665          22  Female        Jewelry  Accessories                     84
# 2670          39  Female           Belt  Accessories                     28
# 2671          30  Female     Sunglasses  Accessories                     44
# ...          ...     ...            ...          ...                    ...
# 3893          35  Female        Jewelry  Accessories                     86
# 3894          21  Female            Hat  Accessories                     64
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends.loc[:,["Shipping Type","Review Rating"]].value_counts()
# Out:
# Shipping Type   Review Rating
# Free Shipping   3.4              42
#                 4.6              41
# Standard        4.6              41
#                 4.4              38
# Store Pickup    2.6              38
#                                  ..
# Standard        5.0               9
# Next Day Air    5.0               9
# Express         2.5               9
# Standard        2.5               8
# 2-Day Shipping  2.5               8
# Length: 156, dtype: int64

# %%
trends.describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.068462              59.764359       3.749949           25.351538
# std      15.207589              23.685392       0.716223           14.447125
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              39.000000       3.100000           13.000000
# 50%      44.000000              60.000000       3.700000           25.000000
# 75%      57.000000              81.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
trends
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends.boxplot(by="Season",column=["Purchase Amount (USD)"])
# Out:
# <Axes: title={'center': 'Purchase Amount (USD)'}, xlabel='Season'>

# %%
trends.boxplot(by="Season",column=["Previous Purchases"])
# Out:
# <Axes: title={'center': 'Previous Purchases'}, xlabel='Season'>

# %%
trends.boxplot(by="Season",column=["Review Rating"])
# Out:
# <Axes: title={'center': 'Review Rating'}, xlabel='Season'>

# %%
trends.boxplot(by="Category",column=["Purchase Amount (USD)"])
# Out:
# <Axes: title={'center': 'Purchase Amount (USD)'}, xlabel='Category'>

# %%
trends.boxplot(by="Category",column=["Age"])
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Category'>
